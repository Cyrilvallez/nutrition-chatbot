# %%
import torch
from transformers import IdeficsForVisionText2Text, AutoProcessor

checkpoint = "HuggingFaceM4/idefics-9b"

processor = AutoProcessor.from_pretrained(checkpoint)

# %%
processor.tokenizer.vocab
# Out:
# {'▁mystery': 29236,
#  '▁między': 29815,
#  '▁taught': 16187,
#  '▁Laz': 19575,
#  'display': 4990,
#  'laus': 15273,
#  '▁folder': 4138,
#  '▁International': 4623,
#  '▁Indians': 17072,
#  '▁stones': 25702,
#  '^{+': 27587,
#  'fore': 1079,
#  'ict': 919,
#  '▁nin': 17081,
#  '▁nazw': 28092,
#  'api': 2754,
#  'secure': 24216,
#  'න': 31609,
#  '▁gioc': 17757,
#  '▁копи': 21526,
#  'uola': 29568,
#  'true': 3009,
#  '▁det': 1439,
#  '▁tre': 2578,
#  'Host': 8514,
#  '▁science': 10466,
#  '▁Bootstrap': 25746,
#  'alloc': 15956,
#  'zeum': 27919,
#  '▁thread': 3244,
#  'locked': 29113,
#  '▁software': 7047,
#  '▁partial': 7687,
#  '▁Revol': 26882,
#  '▁deliber': 23663,
#  'cken': 8916,
#  '▁Eastern': 16162,
#  '创': 31441,
#  '▁cerem': 22059,
#  '▁áll': 13575,
#  '▁periodic': 29591,
#  '▁Bulg': 28126,
#  'Serial': 9125,
#  '▁gig': 19340,
#  '▁continued': 7572,
#  'onial': 25164,
#  '▁Gef': 15759,
#  '▁уже': 20203,
#  '▁highway': 29469,
#  'ḷ': 31802,
#  '▁Recht': 26257,
# ...

# %%
reverse = {v:k for k,v in processor.tokenizer.vocab.items()}

# %%
processor.tokenizer.tokenize("<end_of_utterance>", add_special_tokens=False)
# Out:
# ['▁<', 'end', '_', 'of', '_', 'utter', 'ance', '>']

# %%
reverse[32001]
# Out:
# ''

# %%
bad_words_ids = processor.tokenizer(["", "<fake_token_around_image>"], add_special_tokens=False).input_ids
bad_words_ids
# Out:
# [[32001], [32000]]
